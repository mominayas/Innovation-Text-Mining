# %% [markdown]
# # Strategic Analysis of Innovation Trends using Text Mining & Python

# %% [markdown]
# ## Objective
# This notebook analyzes innovation-related articles to extract trends, topics, and sentiments using Python.

# %%
# Import Libraries
# !pip install pandas matplotlib WordCloud nltk
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

nltk.download('vader_lexicon')
# Out:
# ...
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# ...
# Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------------------------- ---------- 6.0/8.1 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 22.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 19.7 MB/s eta 0:00:00
# Using cached contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...

# %%
# Load Dataset
df = pd.read_csv('innovation_articles.csv')
df.head()
# Out:
#                                    Title        Date           Source  \
# 0  AI Revolutionizes Healthcare Industry  2025-03-15       TechCrunch
# 1   Renewable Energy Innovations in 2025  2025-03-20  GreenTech Media
# 2     Breakthroughs in Quantum Computing  2025-03-25    Science Daily
# 3  Sustainable Packaging Trends Emerging  2025-03-28  Packaging World
# 4  Blockchain Transforming Supply Chains  2025-03-30      CB Insights
#
#                                              Content
# 0  The integration of AI in healthcare is transfo...
# 1  Recent advancements in solar technology and wi...
# 2  Quantum computing has reached new milestones, ...
# 3  Companies are shifting to biodegradable and re...
# 4  Blockchain technology is enhancing transparenc...

# %%
# Generate Word Cloud for all content
text = ' '.join(df['Content'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Sentiment Analysis
sid = SentimentIntensityAnalyzer()
df['Sentiment'] = df['Content'].apply(lambda x: sid.polarity_scores(x)['compound'])

df[['Title', 'Sentiment']]
# Out:
#                                    Title  Sentiment
# 0  AI Revolutionizes Healthcare Industry     0.4939
# 1   Renewable Energy Innovations in 2025     0.4939
# 2     Breakthroughs in Quantum Computing     0.4215
# 3  Sustainable Packaging Trends Emerging     0.3818
# 4  Blockchain Transforming Supply Chains     0.3612
